# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (12, 9)

# %% [markdown]
# ## 통계 기반의 시각화를 제공해주는 Seaborn

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# * survived: 생존여부
# * pclass: 좌석등급
# * sex: 성별
# * age: 나이
# * sibsp: 형제자매 + 배우자 숫자
# * parch: 부모자식 숫자
# * fare: 요금
# * embarked: 탑승 항구
# * class: 좌석등급 (영문)
# * who: 사람 구분
# * deck: 데크
# * embark_town: 탑승 항구 (영문)
# * alive: 생존여부 (영문)
# * alone: 혼자인지 여부

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# * total_bill: 총 합계 요금표
# * tip: 팁
# * sex: 성별
# * smoker: 흡연자 여부
# * day: 요일
# * time: 식사 시간
# * size: 식사 인원

# %% [markdown]
# ## 1. Countplot

# %% [markdown]
# 항목별 갯수를 세어주는 `countplot`
#
# 알아서 해당 column을 구성하고 있는 value들을 구분하여 보여줌

# %% [markdown]
# [countplot 공식 도큐먼트](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
# 배경을 darkgrid 로 설정
sns.set(style='darkgrid')

# %% [markdown]
# ### 1-1 세로로 그리기

# %%
sns.countplot(x="class", hue= "who", data=titanic)

plt.show()

# %% [markdown]
# ### 1-2. 가로로 그리기

# %%
sns.countplot(y="class", hue="who", data=titanic)
    
plt.show()

# %% [markdown]
# ### 1-3. 색상 팔레트 설정

# %%
sns.countplot(x="class", hue="who", palette='copper', data=titanic)
plt.show()

# %% [markdown]
# ## 2. distplot

# %% [markdown]
# matplotlib의 `hist` 그래프와 `kdeplot`을 통합한 그래프
#
# **분포**와 **밀도**를 확인할 수 있다

# %% [markdown]
# [distplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.distplot.html?highlight=distplot#seaborn.distplot)

# %%
# 샘플데이터 생성
x = np.random.randn(100)
x
# Out:
# array([ 8.20098351e-01,  1.17814416e-01,  2.58919963e-01, -1.10531042e+00,
#         3.55198326e-01, -1.01462488e+00,  4.90325319e-01,  9.29602093e-01,
#        -8.34845721e-01, -5.43075660e-01,  7.35293669e-02, -5.17556134e-01,
#        -9.01228202e-01, -1.58425758e-01, -5.77948043e-01,  2.35191946e-01,
#        -1.10039235e-01, -5.23284089e-01,  1.20520561e+00,  4.47190401e-01,
#        -1.08550890e+00,  1.99828730e-01,  6.91314389e-01, -1.27953610e+00,
#        -5.45455825e-01,  7.62935747e-01,  1.51081091e-01,  1.64857710e+00,
#         7.92890257e-01,  3.87347582e-01,  2.21650654e-01, -1.11248332e+00,
#         4.73630733e-01, -2.96046625e-01,  1.38849375e+00,  7.38478836e-01,
#         1.84380811e+00,  2.25606005e+00, -5.41191668e-01,  1.65581995e+00,
#         5.32551014e-01,  4.87043908e-01,  2.45823151e-02, -1.20221903e-01,
#        -5.60015469e-01,  8.32297383e-01,  1.41033162e+00, -7.47912884e-01,
#        -1.11217935e+00, -1.53547214e+00, -6.72102484e-01,  1.56749522e+00,
#        -6.36439046e-01, -3.57510423e-01,  1.03144713e+00, -2.30877581e-02,
#         6.96858562e-01,  8.88510528e-01, -1.03614329e-01,  1.81438418e+00,
#         1.74299322e+00, -3.94864570e-04, -5.58725921e-01, -1.80194771e-01,
#        -2.35768923e+00, -2.31943762e-01, -9.19237313e-01,  1.44184134e+00,
#         4.62324606e-01, -8.84307775e-01, -5.32834481e-01, -1.49391358e+00,
#        -1.11633345e+00, -5.24120664e-01, -4.29237838e-01, -1.11763604e+00,
#         2.33885402e+00, -1.45216031e+00, -5.23306583e-01,  7.71324737e-01,
#         1.01779899e+00, -8.98088993e-01,  1.78529710e+00,  4.51677185e-01,
#        -6.37137952e-01, -1.12848827e+00, -1.12274949e+00, -5.98165777e-01,
#        -2.51096842e-02,  6.86743744e-02,  2.25039902e-01,  1.90097785e-02,
#        -2.03066940e+00,  1.12643952e+00,  5.34442140e-01,  4.02434888e-01,
#         4.34059430e-01, -1.78741451e-01,  7.06092244e-01,  1.42832863e+00])

# %% [markdown]
# ### 2-1. 기본 distplot

# %%
sns.distplot(x)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-2. 데이터가 Series 일 경우

# %%
x = pd.Series(x, name="x variable")
x
# Out:
# 0     0.820098
# 1     0.117814
# 2     0.258920
# 3    -1.105310
# 4     0.355198
#         ...
# 95    0.402435
# 96    0.434059
# 97   -0.178741
# 98    0.706092
# 99    1.428329
# Name: x variable, Length: 100, dtype: float64

# %%
sns.distplot(x)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-3. rugplot

# %% [markdown]
# `rug`는 `rugplot`이라고도 불리우며, 데이터 위치를 x축 위에 **작은 선분(rug)으로 나타내어 데이터들의 위치 및 분포**를 보여준다.

# %%
sns.distplot(x, rug=True, hist=False, kde=True)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-4. kde (kernel density)

# %% [markdown]
# `kde`는 histogram보다 **부드러운 형태의 분포 곡선**을 보여주는 방법

# %%
sns.distplot(x, rug=False, hist=False, kde=True) #히스토그램보다 트렌드를 파악하기 좋음

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-5. 가로로 표현하기

# %%
 sns.distplot(x, vertical=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-6. 컬러 바꾸기

# %%
sns.distplot(x, color="y")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 3. heatmap

# %% [markdown]
# 색상으로 표현할 수 있는 다양한 정보를 **일정한 이미지위에 열분포 형태의 비쥬얼한 그래픽**으로
# 출력하는 것이 특징이다
#
# 응용: 피봇을 시각화하고 싶을 때, 데이터간 상관관계를 보고싶을 때

# %% [markdown]
# [heatmap 도큐먼트](https://seaborn.pydata.org/generated/seaborn.heatmap.html?highlight=heatmap#seaborn.heatmap)

# %% [markdown]
# ### 3-1. 기본 heatmap

# %%
uniform_data = np.random.rand(10, 12)
sns.heatmap(uniform_data, annot=True)

plt.show()

# %% [markdown]
# ### 3-2. pivot table을 활용하여 그리기

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pivot = tips.pivot_table(index='day', columns='size', values='tip')
pivot
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
sns.heatmap(pivot, annot=True, cmap="Blues")

plt.show()

# %% [markdown]
# ### 3-3. correlation(상관관계)를 시각화

# %% [markdown]
# **corr()** 함수는 데이터의 상관관계를 보여준다.

# %%
titanic.corr()
# Out:
#             survived    pclass       age  ...      fare  adult_male     alone
# survived    1.000000 -0.338481 -0.077221  ...  0.257307   -0.557080 -0.203367
# pclass     -0.338481  1.000000 -0.369226  ... -0.549500    0.094035  0.135207
# age        -0.077221 -0.369226  1.000000  ...  0.096067    0.280328  0.198270
# sibsp      -0.035322  0.083081 -0.308247  ...  0.159651   -0.253586 -0.584471
# parch       0.081629  0.018443 -0.189119  ...  0.216225   -0.349943 -0.583398
# fare        0.257307 -0.549500  0.096067  ...  1.000000   -0.182024 -0.271832
# adult_male -0.557080  0.094035  0.280328  ... -0.182024    1.000000  0.404744
# alone      -0.203367  0.135207  0.198270  ... -0.271832    0.404744  1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(titanic.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ## 4. pairplot

# %% [markdown]
# [pairplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot)

# %% [markdown]
# pairplot은 그리도(grid) 형태로 각 **집합의 조합에 대해 히스토그램과 분포도**를 그린다.
#
# 또한, 숫자형 column에 대해서만

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 4-1. 기본 pairplot 그리기

# %%
sns.pairplot(tips)

plt.show()

# %% [markdown]
# ### 4-2. hue 옵션으로 특성 구분

# %%
sns.pairplot(tips, hue='size')
plt.show()

# %% [markdown]
# ### 4-3. 컬러 팔레트 적용

# %%
sns.pairplot(tips, hue='size', palette="rainbow")
plt.show()

# %% [markdown]
# ### 4-4. 사이즈 적용

# %%
sns.pairplot(tips, hue='size', palette="rainbow", height=5,)
plt.show()

# %% [markdown]
# ## 5. violinplot

# %% [markdown]
# 바이올린처럼 생긴 violinplot
#
# column에 대한 **데이터의 비교 분포도**
#
# * 곡선진 부분 (뚱뚱한 부분)은 데이터의 분포
# * 양쪽 끝 뾰족한 부분은 데이터의 최소값과 최대값

# %% [markdown]
# [violinplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.violinplot.html)

# %% [markdown]
# ### 5-1. 기본 violinplot 그리기

# %%
sns.violinplot(x=tips["total_bill"])

plt.show()

# %% [markdown]
# ### 5-2. 비교 분포 확인

# %% [markdown]
# x, y축을 지정해줌으로썬 바이올린을 분할하여 **비교 분포**를 볼 수 있다

# %%
sns.violinplot(x="day", y="total_bill", data=tips)

plt.show()

# %% [markdown]
# ### 5-3. 가로로 뉘인 violinplot

# %%
sns.violinplot(y="day", x="total_bill", data=tips)

plt.show()

# %% [markdown]
# ### 5-4. hue 옵션으로 분포 비교

# %% [markdown]
# 사실 hue 옵션을 사용하지 않으면 바이올린이 대칭이기 때문에 비교 분포의 큰 의미는 없다.
#
# 하지만, hue 옵션을 주면, **단일 column에 대한 바이올린 모양의 비교**를 할 수 있다.

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="muted")
plt.show()

# %% [markdown]
# ### 5-5. split 옵션으로 바이올린을 합쳐서 볼 수 있다.

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="muted", split=True)

plt.show()

# %% [markdown]
# ## 6. lmplot

# %% [markdown]
# `lmplot`은 column 간의 **선형관계를 확인하기에 용이한 차트**
#
# 또한, **outlier**도 같이 짐작해 볼 수 있다.

# %% [markdown]
# [lmplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %% [markdown]
# ### 6-1. 기본 lmplot

# %%
sns.lmplot(x="total_bill", y="tip", height=8, data=tips)

plt.show()

# %% [markdown]
# ### 6-2. hue 옵션으로 다중 선형관계 그리기

# %% [markdown]
# 아래의 그래프를 통하여 비흡연자가, 흡연자 대비 좀 더 **가파른 선형관계**를 가지는 것을 볼 수 있다.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", height=8, data=tips)

plt.show()

# %% [markdown]
# ### 6-3. col 옵션을 추가하여 그래프를 별도로 그려볼 수 있습니다

# %% [markdown]
# 또한, `col_wrap`으로 한 줄에 표기할 column의 갯수를 명시 가능

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="day", col_wrap=2, height=8, data=tips)

plt.show()

# %% [markdown]
# ## 7. relplot

# %% [markdown]
# 두 column간 상관관계를 보지만 `lmplot`처럼 선형관계를 따로 그려주지는 않는다.

# %% [markdown]
# [relplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.relplot.html?highlight=relplot#seaborn.relplot)

# %% [markdown]
# ### 7-1. 기본 relplot

# %%
sns.relplot(x="total_bill", y="tip", hue="day", data=tips)
plt.show()

# %% [markdown]
# ### 7-2. col 옵션으로 그래프 분할

# %%
sns.relplot(x="total_bill", y="tip", hue="day",col="time", data=tips)

plt.show()

# %% [markdown]
# ### 7-3. row와 column에 표기할 데이터 column 선택

# %%
sns.relplot(x="total_bill", y="tip", hue="day", row="sex", col="time", data=tips)
plt.show()

# %% [markdown]
# ### 7-4. 컬러 팔레트 적용

# %%
sns.relplot(x="total_bill", y="tip", hue="day", row="sex", col="time", palette='CMRmap_r', data=tips)
plt.show()

# %% [markdown]
# ## 8. jointplot

# %% [markdown]
# scatter(산점도)와 histogram(분포)을 동시에
#
# 숫자형 데이터만 표현 가능

# %% [markdown]
# [jointplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.jointplot.html?highlight=jointplot#seaborn.jointplot)

# %% [markdown]
# ### 8-1. 기본 jointplot 그리기

# %%
sns.jointplot(x="total_bill", y="tip", height=8, data=tips)

plt.show()

# %% [markdown]
# ### 8-2. 선형관계를 표현하는 regression 라인 그리기

# %% [markdown]
# 옵션에 **kind='reg'**을 추가

# %%
sns.jointplot("total_bill", "tip", height=8, data=tips, kind="reg")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### 8-3. hex 밀도 보기

# %% [markdown]
# **kind='hex'** 옵션을 통해 hex 모양의 밀도를 확인 가능

# %%
sns.jointplot("total_bill", "tip", height=8, data=tips, kind="hex")

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### 8-4. 등고선 모양으로 밀집도 확인하기

# %% [markdown]
# **kind='kde'** 옵션으로 데이터의 밀집도를 보다 부드러운 선으로 확인할 수 있다.

# %%
iris = sns.load_dataset('iris')
sns.jointplot("sepal_width", "petal_length", height=8, data=iris, kind="kde", color="g")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
